# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import os

# %%
from datetime import datetime

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,MinMaxScaler
from sklearn.metrics import mean_squared_log_error

from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer, make_column_transformer

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
import xgboost

# %%
import statsmodels.api as sm
from statsmodels.api import OLS
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plt.rcParams.update({'figure.max_open_warning': 0})
plt.style.use('fivethirtyeight')
cmap_data = plt.cm.Paired
cmap_cv = plt.cm.coolwarm

# %%
def plot_cv_indices(cv, n_splits, X, y, date_col = None):
    """Create a sample plot for indices of a cross-validation object."""
    
    fig, ax = plt.subplots(1, 1, figsize = (11, 7))
    
    # Generate the training/testing visualizations for each CV split
    for ii, (tr, tt) in enumerate(cv.split(X=X, y=y)):
        # Fill in indices with the training/test groups
        indices = np.array([np.nan] * len(X))
        indices[tt] = 1
        indices[tr] = 0

        # Visualize the results
        ax.scatter(range(len(indices)), [ii + .5] * len(indices),
                   c=indices, marker='_', lw=10, cmap=cmap_cv,
                   vmin=-.2, vmax=1.2)


    # Formatting
    yticklabels = list(range(n_splits))
    
    if date_col is not None:
        tick_locations  = ax.get_xticks()
        tick_dates = [" "] + date_col.iloc[list(tick_locations[1:-1])].astype(str).tolist() + [" "]

        tick_locations_str = [str(int(i)) for i in tick_locations]
        new_labels = ['\n\n'.join(x) for x in zip(list(tick_locations_str), tick_dates) ]
        ax.set_xticks(tick_locations)
        ax.set_xticklabels(new_labels)
    
#     ax.set(yticks=np.arange(n_splits+2) + .5, yticklabels=yticklabels,
#            xlabel='Sample index', ylabel="CV iteration",
#            ylim=[n_splits+0.2, -.2])
    ax.legend([Patch(color=cmap_cv(.8)), Patch(color=cmap_cv(.02))],
              ['Testing set', 'Training set'], loc=(1.02, .8))
    ax.set_title('{}'.format(type(cv).__name__), fontsize=15)

# %%
class StoreCatTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, input_features = [], feature_name = "StoreCat"):
        print("\n>>>>>>>>>>init() called.\n")
        self.feature_name = feature_name
        self.input_features = input_features
        
    def fit(self, X, y=None):
        print("\n>>>>>>>>>>fit() called.\n")
        return self
    
    def transform(self, X, y = None):
        print("\n>>>>>>>>>>transform() called.\n")
        X_ = X.copy()
        X_[self.feature_name] = ''
        for col in self.input_features:
            X_[self.feature_name] = X_[self.feature_name] + X_[col]
        le = LabelEncoder()
        X_[self.feature_name] = le.fit_transform(X_[self.feature_name])
        return X_

# %%
class DayOfWeekTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        print("\n>>>>>>>>>>init() called.\n")
        self.dayOfWeekDict = {0:"Monday",
                 1:"Tuesday",
                 2:"Wednesday",
                 3:"Thursday",
                 4:"Friday",
                 5:"Saturday",
                 6:"Sunday"}
        
    def fit(self, X, y=None):
        print("\n>>>>>>>>>>fit() called.\n")
        return self
    
    def transform(self, X, y = None):
        print("\n>>>>>>>>>>transform() called.\n")
        X_ = X.copy()
        X_['Date'] = pd.to_datetime(X_['Date'])
        X_['Year'] = X_['Date'].dt.year
        X_['Month'] = X_['Date'].dt.month
        X_['DayOfWeek'] = X_['Date'].dt.dayofweek
        X_['DayOfWeek'] = X_['DayOfWeek'].apply(lambda x : self.dayOfWeekDict.get(x))
        le = LabelEncoder()
        X_["DayOfWeek"] = le.fit_transform(X_["DayOfWeek"])
        return X_

# %%
class CustomLabelEncode(BaseEstimator, TransformerMixin):
    def __init__(self, feature):
        self.feature = feature
        
    def fit(self, X, y=None):
        return self
    def transform(self, X, y=None):
        X_ = X.copy()
        X_[self.feature] = LabelEncoder().fit_transform(X_[self.feature])
        return X_

# %%
filename = "TRAIN.csv"
testfilename = "TEST_FINAL.csv"

# %%
homedir = os.path.abspath(os.path.dirname("__name__"))

# %%
fp = os.path.join(homedir, filename)
testfp = os.path.join(homedir, testfilename)

# %%
mms = MinMaxScaler()

# %%
df = pd.read_csv(fp)

# %%
df.head()
# Out:
#          ID  Store_id Store_Type Location_Type Region_Code        Date  \
# 0  T1000001         1         S1            L3          R1  2018-01-01
# 1  T1000002       253         S4            L2          R1  2018-01-01
# 2  T1000003       252         S3            L2          R1  2018-01-01
# 3  T1000004       251         S2            L3          R1  2018-01-01
# 4  T1000005       250         S2            L3          R4  2018-01-01
#
#    Holiday Discount  #Order     Sales
# 0        1      Yes       9   7011.84
# 1        1      Yes      60  51789.12
# 2        1      Yes      42  36868.20
# 3        1      Yes      23  19715.16
# 4        1      Yes      62  45614.52

# %%
preprocessor = ColumnTransformer(
    transformers=[
        
        ("DiscountEncoder", CustomLabelEncode("Discount"))
    ], remainder='passthrough'
)

# %%
mycols = ['Store_id', "Date", "Holiday", "Discount", "StoreCat", "DayOfWeek"]

# %%
pipe = Pipeline(steps = [
    ("preprocess",CustomLabelEncode("Discount")),
    ("transform1", StoreCatTransformer(["Store_Type", "Location_Type", "Region_Code"], "StoreCat")),
    ("transform2", DayOfWeekTransformer()),
#     ("selector", ColumnTransformer([
#         ("selector", "passthrough", mycols)
#     ], remainder="drop")),
    
])
# Out:
# >>>>>>>>>>init() called.
#
#
# >>>>>>>>>>init() called.

# %%
df2 = pipe.fit_transform(df)
# Out:
# >>>>>>>>>>fit() called.
#
#
# >>>>>>>>>>transform() called.
#
#
# >>>>>>>>>>fit() called.
#
#
# >>>>>>>>>>transform() called.

# %%
df2.head()
# Out:
#          ID  Store_id Store_Type Location_Type Region_Code       Date  \
# 0  T1000001         1         S1            L3          R1 2018-01-01
# 1  T1000002       253         S4            L2          R1 2018-01-01
# 2  T1000003       252         S3            L2          R1 2018-01-01
# 3  T1000004       251         S2            L3          R1 2018-01-01
# 4  T1000005       250         S2            L3          R4 2018-01-01
#
#    Holiday  Discount  #Order     Sales  StoreCat  Year  Month  DayOfWeek
# 0        1         1       9   7011.84         8  2018      1          1
# 1        1         1      60  51789.12        46  2018      1          1
# 2        1         1      42  36868.20        36  2018      1          1
# 3        1         1      23  19715.16        21  2018      1          1
# 4        1         1      62  45614.52        24  2018      1          1

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2.dtypes
# Out:
# ID                       object
# Store_id                  int64
# Store_Type               object
# Location_Type            object
# Region_Code              object
# Date             datetime64[ns]
# Holiday                   int64
# Discount                  int64
# #Order                    int64
# Sales                   float64
# StoreCat                  int64
# Year                      int64
# Month                     int64
# DayOfWeek                 int64
# dtype: object

# %%
df2.columns
# Out:
# Index(['ID', 'Store_id', 'Store_Type', 'Location_Type', 'Region_Code', 'Date',
#        'Holiday', 'Discount', '#Order', 'Sales', 'StoreCat', 'Year', 'Month',
#        'DayOfWeek'],
#       dtype='object')

# %%
df2.set_index("Date", inplace=True)

# %%
df2.head()
# Out:
#                   ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# Date
# 2018-01-01  T1000001         1         S1            L3          R1        1
# 2018-01-01  T1000002       253         S4            L2          R1        1
# 2018-01-01  T1000003       252         S3            L2          R1        1
# 2018-01-01  T1000004       251         S2            L3          R1        1
# 2018-01-01  T1000005       250         S2            L3          R4        1
#
#             Discount  #Order     Sales  StoreCat  Year  Month  DayOfWeek
# Date
# 2018-01-01         1       9   7011.84         8  2018      1          1
# 2018-01-01         1      60  51789.12        46  2018      1          1
# 2018-01-01         1      42  36868.20        36  2018      1          1
# 2018-01-01         1      23  19715.16        21  2018      1          1
# 2018-01-01         1      62  45614.52        24  2018      1          1

# %%
traindf = df2.loc["2018-01-01":"2018-12-31"]
testdf = df2.loc["2018-10-01":"2019-05-31"]


# traindf =storedf[:trainlen] 
# testdf = storedf[trainlen:]

# %%
traindf.reset_index(inplace=True)

# %%
traindf.shape
# Out:
# (133225, 14)

# %%
traindf["7SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=7).mean().reset_index(0,drop=True)
traindf["7EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=7).mean().reset_index(0,drop=True)

traindf["14SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=14).mean().reset_index(0,drop=True)
traindf["14EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=14).mean().reset_index(0,drop=True)

traindf["30SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=30).mean().reset_index(0,drop=True)
traindf["30EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=30).mean().reset_index(0,drop=True)

traindf["60SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=60).mean().reset_index(0,drop=True)
traindf["60EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=60).mean().reset_index(0,drop=True)

traindf["90SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=90).mean().reset_index(0,drop=True)
traindf["90EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=90).mean().reset_index(0,drop=True)
# Out:
# <ipython-input-33-e1c9864490eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["7SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=7).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["7EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=7).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["14SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=14).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["14EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=14).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["30SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=30).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["30EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=30).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["60SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=60).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["60EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=60).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["90SMA"] = traindf.groupby("Store_id")['Sales'].rolling(window=90).mean().reset_index(0,drop=True)
# <ipython-input-33-e1c9864490eb>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf["90EMA"] = traindf.groupby("Store_id")['Sales'].ewm(span=90).mean().reset_index(0,drop=True)

# %%
traindf.dropna(inplace=True)
# Out:
# <ipython-input-34-739e0a91c5df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   traindf.dropna(inplace=True)

# %%
traindf.head()
# Out:
#             Date        ID  Store_id Store_Type Location_Type Region_Code  \
# 32485 2018-03-31  T1032486       136         S2            L5          R4
# 32486 2018-03-31  T1032487       179         S1            L1          R2
# 32487 2018-03-31  T1032488       336         S4            L2          R1
# 32488 2018-03-31  T1032489        22         S1            L1          R4
# 32489 2018-03-31  T1032490       212         S4            L2          R3
#
#        Holiday  Discount  #Order    Sales  ...          7SMA          7EMA  \
# 32485        0         1      38  28149.0  ...  21618.385714  22686.470619
# 32486        0         1      59  37686.0  ...  39073.238571  38449.953610
# 32487        0         1     165  93981.0  ...  63538.195714  68215.501466
# 32488        0         1      61  47733.0  ...  39253.247143  40450.828317
# 32489        0         1     113  65406.0  ...  55587.557143  55866.692792
#
#               14SMA         14EMA      30SMA         30EMA       60SMA  \
# 32485  23070.407143  23092.869734  24161.530  23991.592353  24405.8155
# 32486  40710.833571  40774.560015  44238.441  43235.105797  44791.3740
# 32487  66840.169286  67215.032256  68697.601  68134.416757  67742.7275
# 32488  41918.552143  41605.791488  43704.403  43345.310973  44184.6125
# 32489  56172.707143  56923.196916  59122.655  58655.178790  59305.3070
#
#               60EMA         90SMA         90EMA
# 32485  24525.224923  25326.645667  24742.811787
# 32486  44671.212480  46677.219333  45247.101605
# 32487  68378.181541  68097.657333  68332.810839
# 32488  44491.832803  46423.637000  45011.900534
# 32489  59721.410805  61495.592000  60188.931262
#
# [5 rows x 24 columns]

# %%
yval = mms.fit_transform(np.array(traindf['Sales']).reshape(-1,1))

# %%
model_gbr = GradientBoostingRegressor(random_state=42)

# %%
X = traindf.loc[:, ('Store_id', 'DayOfWeek', 'StoreCat', 'Discount', 'Holiday', 
                    "7SMA","7EMA", "14SMA", "14EMA","30SMA", "60SMA", "90SMA", "30EMA", "60EMA", "90EMA")]

# %%
model_gbr.fit(X, yval)
# Out:
# /Users/sundara/Documents/venv/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GradientBoostingRegressor(random_state=42)

# %%
importance = model_gbr.feature_importances_

# %%
X.columns.tolist()
# Out:
# ['Store_id',
#  'DayOfWeek',
#  'StoreCat',
#  'Discount',
#  'Holiday',
#  '7SMA',
#  '7EMA',
#  '14SMA',
#  '14EMA',
#  '30SMA',
#  '60SMA',
#  '90SMA',
#  '30EMA',
#  '60EMA',
#  '90EMA']

# %%
collist = X.columns.tolist()

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([collist[x] for x in range(len(importance))], importance)
plt.xticks(rotation=90)
plt.show()
# Out:
# Feature: 0, Score: 0.00000
# Feature: 1, Score: 0.03271
# Feature: 2, Score: 0.00003
# Feature: 3, Score: 0.07949
# Feature: 4, Score: 0.02223
# Feature: 5, Score: 0.01025
# Feature: 6, Score: 0.84767
# Feature: 7, Score: 0.00406
# Feature: 8, Score: 0.00087
# Feature: 9, Score: 0.00153
# Feature: 10, Score: 0.00000
# Feature: 11, Score: 0.00000
# Feature: 12, Score: 0.00107
# Feature: 13, Score: 0.00001
# Feature: 14, Score: 0.00008

# %%
testdf['zSales'] = testdf['Sales']
# Out:
# <ipython-input-43-fa1b1040081f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testdf['zSales'] = testdf['Sales']

# %%
testdf.loc["2019-01-01":"2019-05-31", "zSales"] = 0
# Out:
# /Users/sundara/Documents/venv/lib/python3.9/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
testdf.head()
# Out:
#                   ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# Date
# 2018-10-01  T1099646        85         S4            L2          R1        0
# 2018-10-01  T1099647        86         S1            L1          R4        0
# 2018-10-01  T1099648        14         S3            L2          R4        0
# 2018-10-01  T1099649       131         S4            L2          R1        0
# 2018-10-01  T1099650       102         S4            L2          R1        0
#
#             Discount  #Order    Sales  StoreCat  Year  Month  DayOfWeek  \
# Date
# 2018-10-01         1     145  77082.0        46  2018     10          1
# 2018-10-01         0      50  30138.0         3  2018     10          1
# 2018-10-01         1      75  54834.0        39  2018     10          1
# 2018-10-01         1     130  70011.0        46  2018     10          1
# 2018-10-01         1     101  62481.0        46  2018     10          1
#
#              zSales
# Date
# 2018-10-01  77082.0
# 2018-10-01  30138.0
# 2018-10-01  54834.0
# 2018-10-01  70011.0
# 2018-10-01  62481.0

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.options.mode.chained_assignment = None

# %%
predlist = []
for sid in testdf['Store_id'].unique().tolist():
    sdf = testdf[testdf['Store_id']==sid]
    for ix in [x for x in sdf.index.strftime("%Y-%m-%d").tolist() if x > "2018-12-31"]:
        tempdf = sdf.loc[:ix]
        tempdf = tempdf[-90:]
        
        tempdf["7SMA"] = tempdf.groupby("Store_id")['Sales'].rolling(window=7).mean().reset_index(0,drop=True)
        tempdf["7EMA"] = tempdf.groupby("Store_id")['Sales'].ewm(span=7).mean().reset_index(0,drop=True)

        tempdf["14SMA"] = tempdf.groupby("Store_id")['Sales'].rolling(window=14).mean().reset_index(0,drop=True)
        tempdf["14EMA"] = tempdf.groupby("Store_id")['Sales'].ewm(span=14).mean().reset_index(0,drop=True)
        
        tempdf["60SMA"] = tempdf.rolling(window=60)['zSales'].mean()
        tempdf["60EMA"] = tempdf.ewm(span=60)['zSales'].mean()

        tempdf["30SMA"] = tempdf.rolling(window=30)['zSales'].mean()
        tempdf["30EMA"] = tempdf.ewm(span=30)['zSales'].mean()

        tempdf["90SMA"] = tempdf.rolling(window=90)['zSales'].mean()
        tempdf["90EMA"] = tempdf.ewm(span=90)['zSales'].mean()
        tempdf.dropna(inplace=True)
#         print(ix)
#         print(tempdf.shape)
#         print(tempdf)
        texog = tempdf.loc[:, ('Store_id', 'DayOfWeek', 'StoreCat', 'Discount', 'Holiday',
                                      "7SMA","7EMA", "14SMA", "14EMA","30SMA", "60SMA", "90SMA", "30EMA", 
                                               "60EMA", "90EMA")]
#         print(texog.dtypes)
        pred = model_gbr.predict(texog)
        predlist.append({"ID":tempdf.iloc[0, 0],"Date":ix, "Pred":pred.tolist()[0]})
        sdf.loc[ix, "zSales"] = pred.tolist()[0]
        
#         print(tempdf.tail(1))

# %%
len(predlist)
# Out:
# 55115

# %%
outdf = pd.DataFrame(predlist).set_index("Date")

# %%
outdf.head()
# Out:
#                   ID      Pred
# Date
# 2019-01-01  T1133413  0.217615
# 2019-01-02  T1133705  0.259039
# 2019-01-03  T1134186  0.252660
# 2019-01-04  T1134569  0.301529
# 2019-01-05  T1134797  0.447131

# %%
outdf['zPred'] = mms.inverse_transform(np.array(outdf['Pred']).reshape(-1,1))

# %%
testdf2 = pd.merge(testdf, outdf[["ID", "zPred"]], on="ID", how='left')

# %%
testdf2.dropna(inplace=True)

# %%
testdf2['Pred'] = testdf2['zPred'].apply(lambda x : 0 if x<0 else x)

# %%
testdf2.head()
# Out:
#              ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# 33580  T1133226       304         S1            L1          R4        1
# 33581  T1133227       162         S4            L1          R2        1
# 33582  T1133228       148         S1            L1          R2        1
# 33583  T1133229        94         S4            L2          R2        1
# 33584  T1133230       137         S4            L1          R1        1
#
#        Discount  #Order     Sales  StoreCat  Year  Month  DayOfWeek  zSales  \
# 33580         0      57  45634.50         3  2019      1          5     0.0
# 33581         0      63  41877.45        43  2019      1          5     0.0
# 33582         0      30  23139.00         1  2019      1          5     0.0
# 33583         1      60  43645.20        47  2019      1          5     0.0
# 33584         0      64  40367.70        42  2019      1          5     0.0
#
#               zPred          Pred
# 33580  36565.249862  36565.249862
# 33581  35131.925838  35131.925838
# 33582  23521.686931  23521.686931
# 33583  50368.184854  50368.184854
# 33584  34599.551722  34599.551722

# %%
negativedf = testdf2[testdf2['Pred'] <0]

# %%
testdf2.dropna(inplace=True)

# %%
mean_squared_log_error(testdf2['Sales'], testdf2['Pred'])*1000
# Out:
# 53.49676106263782

# %% [markdown]
# # Test

# %%
combdf = testdf.loc['2019-03-01':'2019-05-31']

# %%
combdf[combdf['Store_id']==1].shape
# Out:
# (92, 14)

# %%
combdf
# Out:
#                   ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# Date
# 2019-03-01  T1154761       121         S1            L1          R4        1
# 2019-03-01  T1154762       176         S4            L2          R3        1
# 2019-03-01  T1154763         3         S4            L2          R1        1
# 2019-03-01  T1154764       195         S4            L1          R1        1
# 2019-03-01  T1154765       255         S3            L2          R4        1
# ...              ...       ...        ...           ...         ...      ...
# 2019-05-31  T1188336       149         S2            L3          R2        1
# 2019-05-31  T1188337       153         S4            L2          R1        1
# 2019-05-31  T1188338       154         S1            L3          R2        1
# 2019-05-31  T1188339       155         S3            L1          R2        1
# 2019-05-31  T1188340       152         S2            L1          R1        1
#
#             Discount  #Order     Sales  StoreCat  Year  Month  DayOfWeek  \
# Date
# 2019-03-01         1      56  39025.98         3  2019      3          0
# 2019-03-01         1     112  69877.83        48  2019      3          0
# 2019-03-01         1      88  42984.00        46  2019      3          0
# 2019-03-01         1     106  59296.86        42  2019      3          0
# 2019-03-01         1      78  53622.66        39  2019      3          0
# ...              ...     ...       ...       ...   ...    ...        ...
# 2019-05-31         1      51  37272.00        22  2019      5          0
# 2019-05-31         0      90  54572.64        46  2019      5          0
# 2019-05-31         0      56  31624.56         9  2019      5          0
# 2019-05-31         1      70  49162.41        33  2019      5          0
# 2019-05-31         0      47  37977.00        17  2019      5          0
#
#             zSales
# Date
# 2019-03-01     0.0
# 2019-03-01     0.0
# 2019-03-01     0.0
# 2019-03-01     0.0
# 2019-03-01     0.0
# ...            ...
# 2019-05-31     0.0
# 2019-05-31     0.0
# 2019-05-31     0.0
# 2019-05-31     0.0
# 2019-05-31     0.0
#
# [33580 rows x 14 columns]

# %%
combdf.shape
# Out:
# (33580, 14)

# %%
validdf = pd.read_csv(testfp)

# %%
validdf2 = pipe.fit_transform(validdf)
# Out:
# >>>>>>>>>>fit() called.
#
#
# >>>>>>>>>>transform() called.
#
#
# >>>>>>>>>>fit() called.
#
#
# >>>>>>>>>>transform() called.

# %%
validdf2['Date'] = pd.to_datetime(validdf2['Date'])

# %%
validdf2.set_index("Date", inplace=True)

# %%
validdf2.shape
# Out:
# (22265, 11)

# %%
validdf2.shape[0] + combdf.shape[0]
# Out:
# 55845

# %%
mixdf = pd.concat([combdf, validdf2])

# %%
mixdf.shape[0]
# Out:
# 55845

# %%
mixdf['zSales'] = mixdf['Sales']

# %%
mixdf.head()
# Out:
#                   ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# Date
# 2019-03-01  T1154761       121         S1            L1          R4        1
# 2019-03-01  T1154762       176         S4            L2          R3        1
# 2019-03-01  T1154763         3         S4            L2          R1        1
# 2019-03-01  T1154764       195         S4            L1          R1        1
# 2019-03-01  T1154765       255         S3            L2          R4        1
#
#             Discount  #Order     Sales  StoreCat  Year  Month  DayOfWeek  \
# Date
# 2019-03-01         1    56.0  39025.98         3  2019      3          0
# 2019-03-01         1   112.0  69877.83        48  2019      3          0
# 2019-03-01         1    88.0  42984.00        46  2019      3          0
# 2019-03-01         1   106.0  59296.86        42  2019      3          0
# 2019-03-01         1    78.0  53622.66        39  2019      3          0
#
#               zSales
# Date
# 2019-03-01  39025.98
# 2019-03-01  69877.83
# 2019-03-01  42984.00
# 2019-03-01  59296.86
# 2019-03-01  53622.66

# %%
mixdf['zSales'].fillna(0, inplace=True)

# %%
mixdf['#Order'].fillna(0, inplace=True)

# %%
mixdf.tail()
# Out:
#                   ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# Date
# 2019-07-31  T1210601       186         S2            L5          R2        0
# 2019-07-31  T1210602        11         S4            L2          R1        0
# 2019-07-31  T1210603       185         S1            L1          R3        0
# 2019-07-31  T1210604        69         S1            L1          R4        0
# 2019-07-31  T1210605       365         S2            L1          R2        0
#
#             Discount  #Order  Sales  StoreCat  Year  Month  DayOfWeek  zSales
# Date
# 2019-07-31         0     0.0    NaN        29  2019      7          6     0.0
# 2019-07-31         0     0.0    NaN        46  2019      7          6     0.0
# 2019-07-31         1     0.0    NaN         2  2019      7          6     0.0
# 2019-07-31         0     0.0    NaN         3  2019      7          6     0.0
# 2019-07-31         0     0.0    NaN        18  2019      7          6     0.0

# %%
validdf2.head()
# Out:
#                   ID  Store_id Store_Type Location_Type Region_Code  Holiday  \
# Date
# 2019-06-01  T1188341       171         S4            L2          R3        0
# 2019-06-01  T1188342       172         S1            L1          R1        0
# 2019-06-01  T1188343       173         S4            L2          R1        0
# 2019-06-01  T1188344       174         S1            L1          R4        0
# 2019-06-01  T1188345       170         S1            L1          R2        0
#
#             Discount  StoreCat  Year  Month  DayOfWeek
# Date
# 2019-06-01         0        48  2019      6          2
# 2019-06-01         0         0  2019      6          2
# 2019-06-01         0        46  2019      6          2
# 2019-06-01         0         3  2019      6          2
# 2019-06-01         0         1  2019      6          2

# %%
predlist = []
for sid in mixdf['Store_id'].unique().tolist():
    sdf = mixdf[mixdf['Store_id']==sid]
    for ix in [x for x in sdf.index.strftime("%Y-%m-%d").tolist() if x > "2019-05-31"]:
        tempdf = sdf.loc[:ix]
        tempdf.drop("Sales", axis=1, inplace=True)
        tempdf = tempdf[-90:]
        
        tempdf["7SMA"] = tempdf.groupby("Store_id")['zSales'].rolling(window=7).mean().reset_index(0,drop=True)
        tempdf["7EMA"] = tempdf.groupby("Store_id")['zSales'].ewm(span=7).mean().reset_index(0,drop=True)

        tempdf["14SMA"] = tempdf.groupby("Store_id")['zSales'].rolling(window=14).mean().reset_index(0,drop=True)
        tempdf["14EMA"] = tempdf.groupby("Store_id")['zSales'].ewm(span=14).mean().reset_index(0,drop=True)
        
        tempdf["60SMA"] = tempdf.rolling(window=60)['zSales'].mean()
        tempdf["60EMA"] = tempdf.ewm(span=60)['zSales'].mean()

        tempdf["30SMA"] = tempdf.rolling(window=30)['zSales'].mean()
        tempdf["30EMA"] = tempdf.ewm(span=30)['zSales'].mean()

        tempdf["90SMA"] = tempdf.rolling(window=90)['zSales'].mean()
        tempdf["90EMA"] = tempdf.ewm(span=90)['zSales'].mean()
#         print(tempdf.head())
#         print(tempdf.tail())
        tempdf.dropna(inplace=True)
#         print(ix)
#         print(tempdf.shape)
#         print(tempdf)
        texog = tempdf.loc[:, ('Store_id', 'DayOfWeek', 'StoreCat', 'Discount', 'Holiday',
                                      "7SMA","7EMA", "14SMA", "14EMA",
                               "30SMA", "60SMA", "90SMA", "30EMA", "60EMA", "90EMA")]
#         print(texog.dtypes)
        pred = model_gbr.predict(texog)
        predlist.append({"ID":tempdf.iloc[0, 0],"Date":ix, "Pred":pred.tolist()[0]})
        sdf.loc[ix, "zSales"] = pred.tolist()[0]
        
#         print(tempdf.tail(1))

# %%
outdf = pd.DataFrame(predlist).set_index("Date")

# %%
outdf['zPred'] = mms.inverse_transform(np.array(outdf['Pred']).reshape(-1,1))

# %%
validmixdf = pd.merge(validdf, outdf[["ID", "zPred"]], on="ID", how='left')

# %%
validmixdf['Sales'] = validmixdf['zPred'].apply(lambda x : 0 if x<0 else x)

# %%
validmixdf[["ID", "Sales"]].to_csv("Submission_{}.csv".format(datetime.now().microsecond), index=None)
